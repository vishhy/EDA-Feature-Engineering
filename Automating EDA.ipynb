# %% [markdown]
# ### 1. Using Pandas Profiling

# %%
# !pip install pandas --upgrade --quiet --user --use-feature=2020-resolver

# %%
pip install pandas-profiling --user --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pandas_profiling
import numpy as np

#importing the data
df = pd.read_csv(r'Dataset\data5\Visadataset.csv')

#descriptive statistics
pandas_profiling.ProfileReport(df)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-09-26 06:01:27.850972&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# Use the following code to get a separate html report file from pandas profiling.
# - > `profile = pandas_profiling.ProfileReport(df)`
# - > `profile.to_file(output.html)`

# %% [markdown]
# ### 2. Using AutoViz

# %%
pip install autoviz --user --quiet --upgrade
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\pc\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyct.exe is installed in 'C:\Users\pc\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\pc\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script bokeh.exe is installed in 'C:\Users\pc\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline

# %%
av = AutoViz_Class()

# %%
df = av.AutoViz(r'Dataset/data5/Visadataset.csv', save_plot_dir=r'EDA/output_autoviz.html')
# Out:
# Shape of your Data Set loaded: (25480, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_5180a_row0_col0, #T_5180a_row0_col4, #T_5180a_row1_col0, #T_5180a_row1_col4, #T_5180a_row8_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...

# %% [markdown]
# ### 3. Using SweetViz

# %%
pip install sweetviz --user --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz
import pandas as pd

# %%
df = pd.read_csv(r'Dataset/data5/Visadataset.csv')

# %%
report = sweetviz.analyze(df)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 4. Using d-tale

# %%
pip install dtale --quiet --user --upgrade
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale

# %%
import pandas as pd
df = pd.read_csv(r'Dataset/data5/Visadataset.csv')

# %%
dtale_report = dtale.show(df)

# %%
dtale_report.open_browser()
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python38\site-packages\seaborn\matrix.py:309: UserWarning:
#
# Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#
# C:\Users\pc\AppData\Roaming\Python\Python38\site-packages\seaborn\matrix.py:309: UserWarning:
#
# Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#
# 2022-09-26 12:30:00,195 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,245 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,278 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,313 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,342 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,362 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2022-09-26 12:30:00,395 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
